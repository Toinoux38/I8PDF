# %% [markdown]
# # How to Create a Jupyter Notebook in VS Code
# Follow the steps below to create, save, and run your first notebook in this workspace.

# %% [markdown]
# ## 1. Open the Jupyter Extension and Create a New Notebook
# - Open the Extensions view and ensure the **Jupyter** extension is installed.
# - Use **Command Palette** → **Jupyter: Create New Blank Notebook**.
# - Confirm the notebook editor opens with a new `.ipynb` file tab.

# %% [markdown]
# ## 2. Select Python Kernel and Save the Notebook
# - Use the **Select Kernel** button in the top-right to pick a Python environment.
# - Save the notebook into your project folder (for example, this workspace) to enable autosave and proper metadata.

# %% [markdown]
# ## 3. Add and Run a Code Cell
# Insert a code cell, write a short Python snippet, then click **Run Cell**.

# %%
# Simple Python snippet
message = "Hello from Jupyter in VS Code!"
message

# %% [markdown]
# ## 4. Verify Output in the Output Pane and Terminal
# - Check the output directly below the code cell.
# - If needed, open **View → Output** or the **Terminal** to inspect logs.
